# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('consumer_psych_recommendation.csv')
# Out:
# /home/mikeal/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    consumer_id consumer_dob  mhtp consumer_gender  \
# 0     90851028   1982-01-01  True               M
# 1     90851028   1982-01-01  True               M
# 2     95763509   1980-01-01  True               F
# 3     90851028   1982-01-01  True               M
# 4     95763509   1980-01-01  True               F
#
#                                          why_looking prev_psych_experiences  \
# 0                                shyness self esteem                    NaN
# 1                                shyness self esteem                    NaN
# 2  Im feeling lost and stuck and confused about m...                    NaN
# 3                                shyness self esteem                    NaN
# 4  Im feeling lost and stuck and confused about m...                    NaN
#
#   diagnosis  proxy_id proxy_first_name proxy_last_name     ...      \
# 0       NaN       1.0              NaN             NaN     ...
# 1       NaN       1.0              NaN             NaN     ...
# ...

# %%
def n_nan(df,column):
    
    # Count nans and find percentage
    
    percentage = df[column].value_counts().sum()/len(df)
    
    print(column, " = ",np.round(percentage*100,1))

# %%
data_columns = data.columns

# %%
for names in data_columns:
    
    n_nan(data, names)
# Out:
# consumer_id  =  100.0
# consumer_dob  =  73.4
# mhtp  =  100.0
# consumer_gender  =  98.0
# why_looking  =  86.2
# prev_psych_experiences  =  2.9
# diagnosis  =  3.6
# proxy_id  =  97.9
# proxy_first_name  =  1.8
# proxy_last_name  =  0.6
# psych_id  =  100.0
# description  =  95.1
# psych_gender  =  94.5
# fees  =  84.1
# headline  =  61.6
# callout1  =  58.7
# callout2  =  57.7
# callout3  =  55.8
# sliding_scale  =  78.3
# is_visible  =  100.0
# bulk_billing  =  80.1
# rebate  =  83.9
# likes_to_do  =  49.1
# psych_dob  =  35.2
# first_session  =  17.8
# ndis  =  16.2
# online_sessions  =  28.1
# practising_since  =  29.5
# therapeutic_approach  =  21.4
# avg_rating  =  39.8
# rating_valid_for_display  =  39.8
# recommendation_id  =  100.0
# preview_display_count  =  100.0
# preview_rank_avg  =  100.0
# self_shortlisted  =  100.0
# staff_shortlisted  =  100.0
# self_matched  =  100.0
# staff_matched  =  100.0
# self_unmatched  =  1.7
# staff_unmatched  =  1.7
# ...

# %%
# Drop all last values

drop_columns = ['rating_avg', 
                'sessions',
                'booked_appt', 
                'sent_message', 
                'viewed', 
                'psych_unmatched',
                'staff_unmatched',
                'self_unmatched',
                'staff_matched',
                'self_matched',
                'staff_shortlisted',
                'recommendation_id',
                'proxy_first_name',
                'proxy_last_name',
                'diagnosis',
                'first_session',
                'ndis',
                'why_looking',
                'description',
                'headline',
                'likes_to_do',
                'therapeutic_approach',
                'callout1',
                'callout2',
                'callout3',
                
                
               ]

# %%
data.drop(drop_columns,1)
# Out:
#         consumer_id consumer_dob   mhtp consumer_gender  \
# 0          90851028   1982-01-01   True               M
# 1          90851028   1982-01-01   True               M
# 2          95763509   1980-01-01   True               F
# 3          90851028   1982-01-01   True               M
# 4          95763509   1980-01-01   True               F
# 5          95763509   1980-01-01   True               F
# 6          90851028   1982-01-01   True               M
# 7          90851028   1982-01-01   True               M
# 8          90851028   1982-01-01   True               M
# 9          93556988   1999-01-01  False               F
# 10         91302178   1987-01-01  False               M
# 11         93177299   1997-01-01  False               F
# 12         90851028   1982-01-01   True               M
# 13         95763509   1980-01-01   True               F
# 14         90851028   1982-01-01   True               M
# 15         95763509   1980-01-01   True               F
# ...

# %%
# map unique values to number 0 to len of number
len(data.why_looking.unique())
# Out:
# 5362

# %%
data.ndis
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5          True
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11        False
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#           ...
# 231559      NaN
# 231560      NaN
# 231561      NaN
# 231562      NaN
# 231563      NaN
# 231564      NaN
# 231565      NaN
# 231566      NaN
# 231567      NaN
# 231568      NaN
# 231569      NaN
# 231570      NaN
# 231571      NaN
# 231572      NaN
# 231573      NaN
# 231574      NaN
# 231575      NaN
# 231576      NaN
# 231577      NaN
# 231578      NaN
# 231579      NaN
# 231580      NaN
# 231581      NaN
# 231582      NaN
# ...
